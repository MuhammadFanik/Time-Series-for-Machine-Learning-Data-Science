# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
df = pd.read_csv("sales.csv")
df.head()
# Out:
#          date  sales
# 0  2022-01-01   1200
# 1  2022-01-02    980
# 2  2022-01-03   1100
# 3  2022-01-04    870
# 4  2022-01-05    760

# %%
df["date"] = pd.to_datetime(df["date"])
df.set_index("date", inplace=True)

# %%
df.head()
# Out:
#             sales
# date
# 2022-01-01   1200
# 2022-01-02    980
# 2022-01-03   1100
# 2022-01-04    870
# 2022-01-05    760

# %%
fig, axes = plt.subplots(2, 1, figsize=(12, 7))
plot_acf(df['sales'], lags=40, ax=axes[0], title='ACF — Original Series')
plot_pacf(df['sales'], lags=40, ax=axes[1], title='PACF — Original Series')

plt.tight_layout()
plt.show()
